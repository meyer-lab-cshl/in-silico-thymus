# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
random.seed(42)
aas = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y']
# Get 9 20x20 matrices. For each position, calculate the differences in energy between aa pairs
# Diagonals should be 0
# Symmetric about diagonals w/ opposite signs
# Get 9 x 24 x 20 x 20, then average over 24

# %%
data = pd.read_csv("./bindingdata.txt", delimiter = "\t", skipfooter=18)
pd.DataFrame(data)
# Out:
# <ipython-input-2-1c9d4cea65bd>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv("./bindingdata.txt", delimiter = "\t", skipfooter=18)
#      SEQ_ID  SEQ_PEPTIDE_NUM SEQ_SEQUENCE Residue  Pos    HLA A*0201  \
# 0     29618        3064.0001    AXXXXXXXX       A    1   1986.241212
# 1     29619        3064.0002    CXXXXXXXX       C    1   7063.823365
# 2     29620        3064.0003    DXXXXXXXX       D    1  29014.896590
# 3     29621        3064.0004    EXXXXXXXX       E    1  15223.257270
# 4     29622        3064.0005    FXXXXXXXX       F    1    227.122044
# ..      ...              ...          ...     ...  ...           ...
# 175   29793        3064.0176    XXXXXXXXS       S    9   8559.034282
# 176   29794        3064.0177    XXXXXXXXT       T    9   4529.713997
# 177   29795        3064.0178    XXXXXXXXV       V    9     68.112936
# 178   29796        3064.0179    XXXXXXXXW       W    9  12744.490470
# 179   29797        3064.0180    XXXXXXXXY       Y    9  34362.840930
#
#      HLA A*30011   HLA B*0801    HLA A*3201     Mamu B*01  ...   HLA B*1501  \
# 0     344.138927  1114.740537   2172.204511  10783.200030  ...   234.477043
# 1     645.862460   779.454784   6949.226313   5399.841033  ...   395.571637
# 2    9025.627626   948.214489  25246.819350  40913.787440  ...  1766.613247
# 3    3552.983642   348.036034   6891.455029   4837.590454  ...   460.592314
# 4    1789.956110   220.865741   8854.619000   6838.599537  ...   124.064501
# ..           ...          ...           ...           ...  ...          ...
# 175   814.158224  5338.697757  33389.597740  66570.345820  ...  4139.816897
# 176  2232.855007  5971.744205  50887.861520  70135.785020  ...  4160.395085
# 177   218.159950   209.289113   3869.588015  13009.076420  ...  1027.518037
# 178  3805.716825  5908.477509    981.135722  12453.094750  ...  2348.720969
# 179   298.518397  5775.343139    829.491513  34811.916250  ...    36.957735
#
#            H-2 Kd        H-2 Db        H-2 Dd        H-2 Kk   Patr A*0301  \
# 0      931.145518  12529.156450   9923.459052   3663.475288    928.127109
# 1     1250.250075  11007.798590   7878.392081   1296.591477   3316.561569
# 2     7545.849931  54592.083370  34598.758760   1528.222937  33845.647570
# 3    10458.861920  60009.919820  12706.601400    854.060139   6271.931304
# 4      540.968127   1805.940907   5987.125560    656.908232   2717.358798
# ..            ...           ...           ...           ...           ...
# 175  12586.201430  78571.428571  77083.333333  78947.368421  13932.983020
# 176   6329.621044  50563.427710  77083.333333  11538.802930  27806.861080
# 177    188.413685   4814.015901  10668.876210    209.208570   4202.216332
# 178   8581.627488  78571.428571   6063.357397   9000.288014  39648.220670
# 179  28583.097520  78571.428571  19173.300900  10328.628890    360.249425
#
#         Mamu B*08    Mamu B*03    HLA A*6802    HLA B*2705
# 0    15172.287240  32205.15880  12329.715780   4992.288678
# 1    10374.247790  59629.53949   2860.247764  15093.191180
# 2    78125.000000  78125.00000   1877.938779  77906.976744
# 3    78125.000000  78125.00000    385.680960  19417.086490
# 4    13562.685720  69451.14337    730.171403   2889.836601
# ..            ...          ...           ...           ...
# 175  33423.326100  68478.30878   3109.117139  43486.812520
# 176  54463.775120  44649.97665   2603.474529  40065.918010
# 177   9595.479736  19738.02039    113.243248   8515.770067
# 178  78125.000000  49311.96681   2511.803557  77906.976744
# 179  24100.000000  53739.54885  11321.480220  14972.611280
#
# [180 rows x 29 columns]

# %%
binding_matr = []

MHCs = list(data.columns[5:])

for i in range(9):
    mhc_energies = []
    for j in range(len(MHCs)):
        energyvals = np.array([float(num) for num in data.loc[data['Pos'] == i+1, MHCs[j]]])
        mhc_energies.append(energyvals - energyvals[:,None])
    binding_matr.append(mhc_energies)
binding_matr = np.array(binding_matr)
avged_binding_matr = np.mean(binding_matr, axis=1)

# %%
pd.DataFrame(binding_matr[0,0], index=aas, columns=aas)
# Out:
#               A             C             D             E             F  \
# A      0.000000   5077.582153  27028.655378  13237.016058  -1759.119168
# C  -5077.582153      0.000000  21951.073225   8159.433905  -6836.701321
# D -27028.655378 -21951.073225      0.000000 -13791.639320 -28787.774546
# E -13237.016058  -8159.433905  13791.639320      0.000000 -14996.135226
# F   1759.119168   6836.701321  28787.774546  14996.135226      0.000000
# G   -556.847722   4520.734431  26471.807656  12680.168336  -2315.966890
# H -45451.352488 -40373.770335 -18422.697110 -32214.336430 -47210.471656
# I    115.918186   5193.500339  27144.573564  13352.934244  -1643.200982
# K    -14.396549   5063.185604  27014.258829  13222.619509  -1773.515717
# L  -2258.357196   2819.224957  24770.298182  10978.658862  -4017.476364
# M   1080.306682   6157.888835  28108.962060  14317.322740   -678.812486
# N  -1385.309854   3692.272299  25643.345524  11851.706204  -3144.429022
# P -67458.203232 -62380.621079 -40429.547854 -54221.187174 -69217.322400
# Q  -9865.428038  -4787.845885  17163.227340   3371.588020 -11624.547206
# R   -709.296042   4368.286111  26319.359336  12527.720016  -2468.415210
# S   -213.248788   4864.333365  26815.406590  13023.767270  -1972.367956
# T   -425.637098   4651.945055  26603.018280  12811.378960  -2184.756266
# V  -1690.706520   3386.875633  25337.948858  11546.309538  -3449.825688
# W  -2027.631443   3049.950710  25001.023935  11209.384615  -3786.750611
# Y   -145.956695   4931.625458  26882.698683  13091.059363  -1905.075863
#
#               G             H             I             K             L  \
# A    556.847722  45451.352488   -115.918186     14.396549   2258.357196
# C  -4520.734431  40373.770335  -5193.500339  -5063.185604  -2819.224957
# D -26471.807656  18422.697110 -27144.573564 -27014.258829 -24770.298182
# E -12680.168336  32214.336430 -13352.934244 -13222.619509 -10978.658862
# F   2315.966890  47210.471656   1643.200982   1773.515717   4017.476364
# G      0.000000  44894.504766   -672.765908   -542.451173   1701.509474
# H -44894.504766      0.000000 -45567.270674 -45436.955939 -43192.995292
# I    672.765908  45567.270674      0.000000    130.314735   2374.275382
# K    542.451173  45436.955939   -130.314735      0.000000   2243.960647
# L  -1701.509474  43192.995292  -2374.275382  -2243.960647      0.000000
# M   1637.154404  46531.659170    964.388496   1094.703231   3338.663878
# N   -828.462132  44066.042634  -1501.228040  -1370.913305    873.047342
# P -66901.355510 -22006.850744 -67574.121418 -67443.806683 -65199.846036
# Q  -9308.580316  35585.924450  -9981.346224  -9851.031489  -7607.070842
# R   -152.448320  44742.056446   -825.214228   -694.899493   1549.061154
# S    343.598934  45238.103700   -329.166974   -198.852239   2045.108408
# T    131.210624  45025.715390   -541.555284   -411.240549   1832.720098
# L  -3750.785935   3100.023166  31077.372362  11289.449354   2835.861668
# M      0.000000   6850.809101  34828.158297  15040.235290   6586.647604
# N  -6850.809101      0.000000  27977.349196   8189.426188   -264.161498
# P -34828.158297 -27977.349196      0.000000 -19787.923007 -28241.510693
# Q -15040.235290  -8189.426188  19787.923007      0.000000  -8453.587686
# R  -6586.647604    264.161498  28241.510693   8453.587686      0.000000
# S  -3980.658173   2870.150929  30847.500124  11059.577117   2605.989431
# T  -8273.602807  -1422.793706  26554.555490   6766.632482  -1686.955204
# V  -7208.482317   -357.673216  27619.675980   7831.752972   -621.834713
# W  -6376.207908    474.601193  28451.950389   8664.027382    210.439696
# Y   -686.330954   6164.478147  34141.827343  14353.904335   5900.316650
#
#               S             T             V             W             Y
# A  -3974.729029    318.215606   -746.904885  -1579.179294  -7269.056248
# C  -1255.406741   3037.537893   1972.417403   1140.142994  -4549.733960
# D -20164.350546 -15871.405912 -16936.526402 -17768.800811 -23458.677765
# E -10493.547911  -6200.603277  -7265.723767  -8097.998176 -13787.875130
# F    658.958299   4951.902933   3886.782443   3054.508034  -2635.368920
# G  -7442.067304  -3149.122670  -4214.243160  -5046.517569 -10736.394523
# H   -254.114428   4038.830207   2973.709717   2141.435308  -3548.441646
# I    452.117984   4745.062618   3679.942128   2847.667719  -2842.209235
# K  -4351.010133    -58.065499  -1123.185989  -1955.460398  -7645.337352
# L    229.872238   4522.816872   3457.696382   2625.421973  -3064.454981
# M   3980.658173   8273.602807   7208.482317   6376.207908    686.330954
# N  -2870.150929   1422.793706    357.673216   -474.601193  -6164.478147
# P -30847.500124 -26554.555490 -27619.675980 -28451.950389 -34141.827343
# Q -11059.577117  -6766.632482  -7831.752972  -8664.027382 -14353.904335
# R  -2605.989431   1686.955204    621.834713   -210.439696  -5900.316650
# S      0.000000   4292.944634   3227.824144   2395.549735  -3294.327219
# T  -4292.944634      0.000000  -1065.120490  -1897.394899  -7587.271853
# V  -3227.824144   1065.120490      0.000000   -832.274409  -6522.151363
# W  -2395.549735   1897.394899    832.274409      0.000000  -5689.876954
# Y   3294.327219   7587.271853   6522.151363   5689.876954      0.000000

# %%
def get_proportional_matrix(MHCs, data):
    total = []

    for i in range(9):
        mhc_energies = []
        for j in range(len(MHCs)):
            energyvals = np.array([float(num) for num in data.loc[data['Pos'] == i+1, MHCs[j]]])
            mhc_energies.append(energyvals)
        total.append(mhc_energies)
    total = np.array(total)
    tot = np.mean(total, axis=1)
    aa_matrices = []
    for i in range(9):
        mat = tot[i]
        aa_matrices.append(mat / mat[:,None])
    return np.array(aa_matrices)

def calculate_reactions(matrix, num_peptides=1000000, num_tcrs=1000000, num_sims=100000, N=9, 
                        aas=['A','C','D','E','F','G','H','I','K','L','M','N','P','Q','R','S','T','V','W','Y']):
    peptides = np.zeros(num_peptides, dtype=object)
    tcrs = np.zeros(num_tcrs, dtype=object)
    for i in range(len(peptides)):
        peptides[i] = ''.join(random.choice(aas) for _ in range(N))
        tcrs[i] = ''.join(random.choice(aas) for _ in range(N))

    reactions = np.zeros(num_sims)
    for sim in range(num_sims):
        reaction = 1.0
        peptide = random.choice(peptides)
        tcr = random.choice(tcrs)
        for i in range(len(peptide)):
            peptide_aa = aas.index(peptide[i])
            tcr_aa = aas.index(tcr[i])
            reaction *= matrix[i, tcr_aa, peptide_aa]

        # reaction is geometric mean of aa interactions
        reaction = reaction**(1/len(peptide))
        reactions[sim] = reaction
    return reactions

# %%
#for i in range(9):
#    strname = "proportional_binding_matrix_position" + str(i+1) + ".csv"
#    pd.DataFrame(aa_matrices[i], index=aas, columns=aas).to_csv('./' + strname)
#for i in range(9):
#    strname = "additive_binding_matrix_position" + str(i+1) + ".csv"
#    pd.DataFrame(avged_binding_matr[i], index=aas, columns=aas).to_csv('./' + strname)
#with open('proportional_binding_matrices.npy', 'wb') as f:
#    np.save(f, aa_matrices)

# %%
MHCs = list(data.columns[5:])
aa_matrices = get_proportional_matrix(MHCs, data)
reactions = calculate_reactions(aa_matrices)
print("Mean reaction strength: " + str(np.mean(reactions)))
print("Median reaction strength: " + str(np.median(reactions)))
print("Standard deviation of reaction strength: " + str(np.std(reactions)))
#pd.DataFrame(aa_matrices[0], index=aas, columns=aas)
# Out:
# Mean reaction strength: 1.0273608001298113
# Median reaction strength: 0.999260876269608
# Standard deviation of reaction strength: 0.24355498522284483

# %%
MHCs = [data.columns[-8]]
aa_matrices_2 = get_proportional_matrix(MHCs, data)
reactions_2 = calculate_reactions(aa_matrices_2)
print("Mean reaction strength: " + str(np.mean(reactions_2)))
print("Median reaction strength: " + str(np.median(reactions_2)))
print("Standard deviation of reaction strength: " + str(np.std(reactions_2)))
#pd.DataFrame(aa_matrices_2[0], index=aas, columns=aas)
# Out:
# Mean reaction strength: 1.108922012201977
# Median reaction strength: 0.9992161750913735
# Standard deviation of reaction strength: 0.529984068234454

# %%
fig = plt.figure(figsize=(10,10))

ax2 = fig.add_subplot(111)
cax1 = ax2.hist(reactions, bins=30, alpha=0.75, label="MHC Average")
cax2 = ax2.hist(reactions_2, bins=30, alpha=0.25, label="Only H-2 Db")
ax2.set_xlabel("Reaction Strength")
ax2.set_ylabel("Count")
ax2.legend()

plt.show()

# %%
fig = plt.figure(figsize=(15,15))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)
mat1 = ax1.matshow(aa_matrices[0], cmap='coolwarm')
mat2 = ax2.matshow(aa_matrices_2[0], cmap='coolwarm')
fig.colorbar(mat1, ax = ax1)
fig.colorbar(mat2, ax = ax2)
#fig.suptitle("Reaction Data",fontsize=16)

xaxis = np.arange(len(aas))
ax1.set_xticks(xaxis)
ax1.set_yticks(xaxis)
ax1.set_xticklabels(aas)
ax1.set_yticklabels(aas)

ax2.set_xticks(xaxis)
ax2.set_yticks(xaxis)
ax2.set_xticklabels(aas)
ax2.set_yticklabels(aas)

plt.show()

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(121)
mat1 = ax.matshow(aa_matrices[0], cmap='coolwarm')

xaxis = np.arange(len(aas))
ax.set_xticks(xaxis)
ax.set_yticks(xaxis)
ax.set_xticklabels(aas)
ax.set_yticklabels(aas)

divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(mat1, cax=cax, orientation='vertical')

ax2 = fig.add_subplot(122)
mat2 = ax2.matshow(aa_matrices_2[0], cmap='coolwarm')

ax2.set_xticks(xaxis)
ax2.set_yticks(xaxis)
ax2.set_xticklabels(aas)
ax2.set_yticklabels(aas)

divider = make_axes_locatable(ax2)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(mat2, cax=cax, orientation='vertical')

plt.show()
